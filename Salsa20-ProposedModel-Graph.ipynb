# %%
import pandas as pd
excel_file_path = 'D:\YahyaData\OutPut\Analysis\Salsa20-Comparison.xlsx'

# Read the Excel file into a pandas DataFrame
df = pd.read_excel(excel_file_path)

# Display the DataFrame (optional)
print(df)
# Out:
#      Message  Salsa-20  Proposed-Model
# 0          1        43              46
# 1          2        44              46
# 2          3        47              51
# 3          4        47              53
# 4          5        48              53
# ..       ...       ...             ...
# 796      797       178             288
# 797      798       178             283
# 798      799       183             294
# 799      800       179             280
# 800      801       180             289
#
# [801 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
message = df['Message']

# Plot the data
plt.figure(figsize=(6, 4))
plt.plot(message, df['Salsa-20'], label='Salsa-20')
plt.plot(message, df['Proposed-Model'], label='Proposed Model')

# Customize the chart
plt.title('Comparison of Salsa-20 and Proposed Model')
plt.xlabel('Message')
plt.ylabel('Values')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Calculate the mean values for 'Salsa-20' and 'Proposed Model'
mean_salsa20 = df['Salsa-20'].mean()
mean_proposed_model = df['Proposed-Model'].mean()

# Plot the bar chart
plt.figure(figsize=(3, 4))
plt.bar(['Salsa-20', 'Proposed-Model'], [mean_salsa20, mean_proposed_model], color=['blue', 'orange'])
#plt.title('Average Values Comparison: Salsa-20 vs. Proposed Model')
#plt.xlabel('Model')
plt.ylabel('Average Values')
plt.show()
